# %% [markdown]
# # Tutorial for scattered x-ray image processing

# %% [markdown]
# This code is a brief summary of how .dat images can be analyzed and visualized to extract information about bragg rods

# %% [markdown]
# ### Importing necessary libraries

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import os.path
from scipy.signal import find_peaks

# %% [markdown]
# ### Creating directory to store neccessary data

# %%
directory='../Data/dat/datswep/0.2deg/' #path to the digital image data, make directory named 0.2deg in datswep to store data
lst=os.listdir(directory)
direct=os.path.abspath('../Data/dat/datswep/0.2deg/')
lst.sort()
print(lst)
# Out:
# ['SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000003_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000004_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000005_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000006_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000007_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000008_SAXS.dat', 'SNS_C72_16.1keV0.2deg_sweep20deg_000009_SAXS.dat']

# %% [markdown]
# ### Finding bragg rods on .dat image

# %%
s1=np.loadtxt('../Data/dat/datswep/0.2deg/SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat')
peaks, _ = find_peaks(s1[531,:],threshold=None,distance=23)
print(peaks)
#rods=peaks[int(len(peaks)/2):]
print(len(peaks))
rods=peaks[int(len(peaks)/2)+3:] #only using the most intense bragg rods by looking at peaks in image
print(rods)
pixel_size=172e-6
total_pixel_y_dir=1043
center_of_y_h=0.059 #center of digital image is pixel number (x,y)=(556,1043-614)*172e-6=(0.095632,0.073788)
print(len(rods))
# Out:
# [ 21  50  78 105 131 158 185 211 237 264 290 318 345 370 398 424 451 477
#  505 531 559 585 611 638 665 691 718 744 772 799 824 851 877 905 931 959]
# 36
# [585 611 638 665 691 718 744 772 799 824 851 877 905 931 959]
# 15

# %% [markdown]
# ### Making directory 'data_0.2deg' to hold data

# %%
for item in lst:
    if os.path.isdir('data_0.2deg/folder%s'%(item[:-4])): 
        pass
    else:
        os.mkdir('data_0.2deg/folder%s'%(item[:-4])) # making directory for data
    ary=np.loadtxt('%s%s'%(directory,item))
    qy=ary[601,:]    
    for i in range(len(rods)):
        qz=ary[:,rods[i]]
        #print(qz)
        np.savetxt('data_0.2deg/folder%s/%sm=%s.dat'%(item[:-4],item[:-4],i),np.c_[list(range(len(qz),0,-1)),qz],delimiter=' ')
        #np.savetxt stored the data in the new directory 'data_0.2deg'

# %% [markdown]
# ### Visualizing data

# %%
for item in lst: # this cell plots intensity on a log scale vs the y axis of image for each bragg rod
    for i in range(1,10):
        fff=np.loadtxt('data_0.2deg/folder%s/%sm=%s.dat'%(item[:-4],item[:-4],i))
        print(item,i)
        x=fff[:,0]
        y=fff[:,1]
        plt.plot(x*pixel_size-center_of_y_h,y)
        plt.yscale('log')
        plt.show()
# Out:
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 1
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 2
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 3
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 4
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 5
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 6
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 7
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 8
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 9
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 1
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 2
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 3
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 4
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 5
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 6
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 7
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 8
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 9
# ...

# %% [markdown]
# ### Getting rid of intervals of 0 values (points in graph that go to 0 dont accurately reflect the data)

# %%
for item in lst: # this cell plots intensity vs the y axis of image for each bragg rod
    for i in range(0,15):
        newdata=open('data_0.2deg/folder%s/%snm=%s.dat' %(item[:-4],item[:-4],i),'w')
        fff=np.loadtxt('data_0.2deg/folder%s/%sm=%s.dat'%(item[:-4],item[:-4],i))
#        print(item,i)
        x=fff[:,0]
        y=fff[:,1]
        for j in range(len(y)):
            if y[j]<=0:
                pass
            else:
                 newdata.write('%s %s\n'%(x[j],y[j]))    
        newdata.close()
        
for item in lst: # this cell plots intensity vs the y axis of image for each bragg rod
    for i in range(1,10):
        fff=np.loadtxt('data_0.2deg/folder%s/%snm=%s.dat'%(item[:-4],item[:-4],i))
        print(item,i)
        x=fff[:,0]
        y=fff[:,1]
        plt.plot(x*pixel_size-center_of_y_h,y)
        plt.yscale('log')
        plt.show()
# Out:
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 1
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 2
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 3
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 4
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 5
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 6
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 7
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 8
# SNS_C72_16.1keV0.2deg_sweep20deg_000001_SAXS.dat 9
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 1
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 2
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 3
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 4
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 5
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 6
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 7
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 8
# SNS_C72_16.1keV0.2deg_sweep20deg_000002_SAXS.dat 9
# ...

# %% [markdown]
# ### averaging 9 runs per trial for 15 trials

# %%
for i in range(0,15):
    #print(i)
    for item in lst[0:]: 
        fff=np.loadtxt('data_0.2deg/folder%s/%snm=%s.dat'%(item[:-4],item[:-4],i))
        #print(item)
        x=fff[:,0]
        y=fff[:,1]
        plt.plot(x,y,label='%s'%item[:-4])
        plt.xlim(400,1100)
        plt.yscale('log') 
#        plt.legend()
    plt.show()

# %% [markdown]
# ### Making directory to hold average data

# %%
if os.path.isdir('data_0.2deg/average'): # creating a directory in data_0.2 for averages
    pass
else:
    os.mkdir('data_0.2deg/average')

# %%
for i in range(0,15): # all plots are suppressed. To visualize, delete hashtags as neccessary
#    print(i)
    a=[]
    b=[]
    v=np.loadtxt('data_0.2deg/folderSNS_C72_16.1keV0.2deg_sweep20deg_000003_SAXS/SNS_C72_16.1keV0.2deg_sweep20deg_000003_SAXSm=%s.dat'%i)
    a=v[:,0]
#    y=open("data/average/m=%s"%i,"w")
    b=v[:,1]
    b=b-b
#    print(b[0])
    for item in lst[3:]: 
        fff=np.loadtxt('data_0.2deg/folder%s/%sm=%s.dat'%(item[:-4],item[:-4],i))
        x=fff[:,0]
        y=fff[:,1]
        b=b+y
#        print(b[0])
#    y.write("%s %s\n"%(a,b))
    np.savetxt('data_0.2deg/average/m=%s.dat'%(i),np.c_[a*pixel_size-center_of_y_h,b/10],delimiter=' ')# saving data to new dir
    plt.plot(a*pixel_size-center_of_y_h,b)
    plt.yscale('log')    
#    plt.xlim(0,0.155)  # to look at other sections of the graphs adjust the values
    plt.show()
